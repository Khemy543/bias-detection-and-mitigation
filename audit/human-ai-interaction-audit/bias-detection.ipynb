# %%
# To evaluate how humans interact with, rely on, or override AI model outputs, and detect 
# whether those interactions introduce new biases — even when the model itself is fair.

# In recruitment systems (like yours), this means examining how:

# Recruiters or HR staff interpret AI recommendations,

# Humans adjust or ignore AI suggestions differently across demographic groups,

# Human–AI collaboration reinforces, amplifies, or mitigates bias.
